# %% [markdown]
# <a href="https://colab.research.google.com/github/ashw6/stml-b40/blob/main/2303A52089.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment-5[1]

# %% [markdown]
# HTNO:2303A52089
# Name:Ashwitha reddy

# %%
import pandas as pd
file_path='salary.xls'
data=pd.read_excel(file_path)
print(data.head())
X=data.iloc[:,:-1]
Y=data.iloc[:,-1]
print("Features:\n",X.head())
print("Target:\n",Y.head())
import matplotlib.pyplot as plt
for column in X.columns:
  plt.figure(figsize=(8,6))
  plt.scatter(X[column],Y,alpha=0.5)
  plt.title(f'{column} vs Target')
  plt.xlabel(column)
  plt.ylabel('Target')
  plt.show()
  from sklearn.preprocessing import MinMaxScaler
  #Create a scaler object
  scaler=MinMaxScaler()
  #Normalize the features and target
  X_normalized=scaler.fit_transform(X)
  Y_normalized=scaler.fit_transform(Y.values.reshape(-1,1))
  #Convert back to DataFrame for easier handling
  X_normalized=pd.DataFrame(X_normalized, columns=X.columns)
  Y_normalized=pd.Series(Y_normalized.flatten(), name='Targer')
  #Display the normalized data
  print("Normalized Features: \n", X_normalized.head())
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# Features:
#     YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# Target:
#  0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# Name: Salary, dtype: int64
# Normalized Features:
#     YearsExperience
# 0         0.000000
# 1         0.021277
# 2         0.042553
# 3         0.095745
# 4         0.117021

# %% [markdown]
# Assignment-5[2]

# %%
import pandas as pd
file_path='diabetes.xls'
data=pd.read_excel(file_path)
print(data.head())
X=data.iloc[:,:-1]
Y=data.iloc[:,-1]
print("Features:\n",X.head())
print("Target:\n",Y.head())
import matplotlib.pyplot as plt
for column in X.columns:
  plt.figure(figsize=(8,6))
  plt.scatter(X[column],Y,alpha=0.5)
  plt.title(f'{column} vs Target')
  plt.xlabel(column)
  plt.ylabel('Target')
  plt.show()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...
