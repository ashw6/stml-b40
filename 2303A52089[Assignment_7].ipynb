# %% [markdown]
# <a href="https://colab.research.google.com/github/ashw6/stml-b40/blob/main/2303A52089%5BAssignment_7%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Step 1: Read the data
data = pd.read_csv('Salary_Data.csv')

# Step 2: Extract features and target
X = data[['YearsExperience']]
y = data['Salary']

# Step 3: Create a linear regression model and fit it
model = LinearRegression()
model.fit(X, y)

# Step 4: Predict values using the model (best fit line)
y_pred = model.predict(X)

# Step 5: Plot the graph
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Best fit line')
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Step 1: Read the data
data = pd.read_csv('assignment_6.csv')

# Step 2: Define feature and target variables
X = data[['Feature 1']]  # You can change this to other features like 'Feature 2', etc.
y = data['Target (Y)']
print(data)

# Display the first few rows to understand its structure
data.head()


# Step 3: Create a linear regression model and fit it
model = LinearRegression()
model.fit(X, y)

# Step 4: Predict values using the model (best fit line)
y_pred = model.predict(X)

# Step 5: Plot the graph between the feature and target
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Best fit line')
plt.title('Feature 1 vs Target (Y)')
plt.xlabel('Feature 1')
plt.ylabel('Target (Y)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#    Feature 1  Feature 2  Feature 3  Feature 4  Target (Y)
# 0        1.2        2.3        3.1        4.2        15.6
# 1        2.4        1.9        2.8        3.5        13.1
# 2        3.5        2.7        1.5        2.9        12.4
# 3        4.1        3.0        3.6        4.8        18.2
# 4        1.9        2.8        2.5        3.2        14.1
# 5        3.7        2.5        1.9        4.0        16.0
# 6        2.1        3.2        2.2        4.1        14.5
# 7        3.3        2.4        3.0        4.5        17.3
# 8        2.8        3.1        1.8        3.6        14.9
# 9        4.0        3.3        2.7        4.9        19.2
